# %%
from read_skeleton import read_skeleton as rs

# %%
skeleton_data = rs('/dataset/NTU/nturgb+d_skeletons/S017C003P020R002A060.skeleton')

# %%
type(skeleton_data)
# Out:
# dict

# %%
len(skeleton_data)
# Out:
# 77

# %%
per_frame = skeleton_data['1']
len(per_frame), len(per_frame[0]), len(per_frame[1]), len(per_frame[0][0])
#frame{person x keypoint x (X,Y,Z)}
# Out:
# (2, 25, 25, 3)

# %%
import numpy as np
import pickle as pk

ntu_npy = '/users/neuron2/Kinetic-GAN/data/NTU/train_data.npy'
ntu_label = '/users/neuron2/Kinetic-GAN/data/NTU/train_label.pkl'

# %%
data = np.load(ntu_npy)

with open(ntu_label, 'rb') as f:
    label = pk.load(f)

# %%
data.shape
# Out:
# (40091, 3, 300, 25, 2)

# %%
label[1]#40091 x 29 x 1
# Out:
# [4,
#  26,
#  22,
#  23,
#  59,
#  52,
#  42,
#  49,
#  13,
#  54,
#  16,
#  35,
#  26,
#  4,
#  17,
#  55,
#  40,
#  5,
#  59,
#  2,
#  16,
#  5,
#  32,
#  44,
#  37,
#  22,
#  0,
#  14,
#  29,
#  15,
#  56,
#  19,
#  6,
#  20,
#  28,
#  36,
#  4,
#  43,
#  41,
#  28,
#  27,
#  13,
#  0,
#  3,
#  54,
#  54,
#  55,
#  18,
#  31,
#  50,
#  24,
#  31,
#  14,
#  43,
#  47,
#  4,
#  57,
#  12,
#  22,
#  46,
#  59,
#  26,
#  33,
#  49,
#  27,
#  1,
#  35,
#  32,
#  26,
#  32,
#  4,
#  46,
#  33,
#  42,
#  15,
#  19,
#  42,
#  54,
#  53,
#  46,
#  30,
#  1,
#  35,
#  33,
#  12,
#  30,
#  15,
#  15,
#  41,
#  12,
#  53,
#  45,
#  49,
#  51,
#  16,
#  4,
#  49,
#  57,
#  36,
#  4,
#  36,
#  37,
#  37,
#  2,
#  28,
#  19,
#  48,
#  12,
#  47,
#  57,
#  22,
#  2,
#  12,
#  17,
#  45,
#  45,
#  26,
#  31,
#  50,
#  28,
#  48,
#  52,
#  22,
#  38,
#  12,
#  26,
#  49,
#  7,
#  23,
#  45,
#  0,
#  54,
#  53,
#  47,
#  46,
#  10,
#  47,
#  33,
#  52,
#  0,
#  56,
#  29,
#  9,
#  26,
#  14,
#  1,
# ...
